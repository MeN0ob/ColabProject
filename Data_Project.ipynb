# %% [markdown]
# <a href="https://colab.research.google.com/github/MeN0ob/ColabProject/blob/main/Data_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

# !pip install pandas
import pandas as pd

# !pip install numpy
import numpy as np

# !pip install seaborn
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-218b73b8-c340-484e-84e8-95f6188ae244" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-218b73b8-c340-484e-84e8-95f6188ae244">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('2024_FACTS_Table_A-10.xlsx')
df.head()
# Out:
#   Table A-10: Applicants to U.S. MD-Granting Medical Schools by Race/Ethnicity (Alone) and State of Legal Residence, Academic Year 2024-2025  \
# 0                                       <facts_year>
# 1  The table below displays the self-identified r...
# 2                                                NaN
# 3                                                NaN
# 4             Applicants by State of Legal Residence
#
#   Unnamed: 1                          Unnamed: 2 Unnamed: 3  \
# 0        NaN                                 NaN        NaN
# 1        NaN                                 NaN        NaN
# 2        NaN                                 NaN        NaN
# 3        NaN                                 NaN        NaN
# 4        NaN  American Indian \nor Alaska Native      Asian
#
#                     Unnamed: 4                                 Unnamed: 5  \
# 0                          NaN                                        NaN
# ...

# %%
df.isnull().sum()
# Out:
# Table A-10: Applicants to U.S. MD-Granting Medical Schools by Race/Ethnicity (Alone) and State of Legal Residence, Academic Year 2024-2025    58
# Unnamed: 1                                                                                                                                    14
# Unnamed: 2                                                                                                                                    10
# Unnamed: 3                                                                                                                                    10
# Unnamed: 4                                                                                                                                    10
# Unnamed: 5                                                                                                                                    10
# ...

# %%
dfdrop=df.dropna()
print(len(dfdrop.index))
print(dfdrop.isnull().sum())
# Out:
# 4
# Table A-10: Applicants to U.S. MD-Granting Medical Schools by Race/Ethnicity (Alone) and State of Legal Residence, Academic Year 2024-2025    0
# Unnamed: 1                                                                                                                                    0
# Unnamed: 2                                                                                                                                    0
# Unnamed: 3                                                                                                                                    0
# Unnamed: 4                                                                                                                                    0
# Unnamed: 5                                                                                                                                    0
# ...

# %% [markdown]
# Are certain racial or ethnic groups underrepersented in matriculants compared to applicants?
